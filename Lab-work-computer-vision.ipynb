# %% [markdown]
# # Ethical issues with computer vision applications

# %% [markdown]
# I think there are quite a few issues with biases in image recognition and privacy in  facial recognition
#
# One of the articles on biases here explains how one of the image recognition softwares using FB and Microsoft image collection was linking images of shopping and washing to women, while coaching and shooting to men. Machine-learning software trained on the datasets didn’t just mirror those biases, it amplified them. As an example, one of the photos depicting a man at a stove was labeled “woman.”
#
# [Machines Taught by Photos Learn a Sexist View of Women<br/>
# Algorithms showed a tendency to associate women with shopping and men with shooting](https://www.wired.com/story/machines-taught-by-photos-learn-a-sexist-view-of-women/)
#
# Another, quite concerning topic is the use of face recognition in police states e.g. Russia:
#
#
# [Russia's lockdown surveillance measures need regulating, rights groups say](https://www.reuters.com/article/uk-health-coronavirus-russia-facial-reco/russias-lockdown-surveillance-measures-need-regulating-rights-groups-say-idUKKCN2253CG?edition-redirect=uk)
#
#
# And, it is also interesting how society is findnig creative ways to fight back, e.g., this story on how to create anti-surveillance make-up using contrasting shades and shapes to make faces unrecognizable as human:
#
# [LEARN HOW TO CREATE AN ANTI-SURVEILLANCE MAKE-UP LOOK WITH PUSSY RIOT](https://www.dazeddigital.com/beauty/head/article/50726/1/learn-how-to-create-an-anti-surveillance-make-up-look-with-pussy-riot)

# %%
print("Too many beers")
# %matplotlib inline
from IPython.display import Image
Image('beers.png')
# Out:
# Too many beers

# %%
#looks pretty accurate considering the bluriness

# %%
print("sunday on the lake")
Image('lake.png')
# Out:
# sunday on the lake

# %%
#very weekend-y looking so pretty accurate
